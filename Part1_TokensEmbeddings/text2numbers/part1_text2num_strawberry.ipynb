# %% [markdown]
# |<h2>Course:</h2>|<h1><a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">A deep understanding of AI language model mechanisms</a></h1>|
# |-|:-:|
# |<h2>Part 1:</h2>|<h1>Tokenizations and embeddings<h1>|
# |<h2>Section:</h2>|<h1>Words to tokens to numbers<h1>|
# |<h2>Lecture:</h2>|<h1><b>How many "r"s in strawberry?<b></h1>|
#
# <br>
#
# <h5><b>Teacher:</b> Mike X Cohen, <a href="https://sincxpress.com" target="_blank">sincxpress.com</a></h5>
# <h5><b>Course URL:</b> <a href="https://udemy.com/course/dullms_x/?couponCode=202508" target="_blank">udemy.com/course/dullms_x/?couponCode=202508</a></h5>
# <i>Using the code without the course may lead to confusion or errors.</i>

# %%
# GPT-4's tokenizer
# !pip install tiktoken
import tiktoken
tokenizer = tiktoken.get_encoding('cl100k_base')
# Out:
# Requirement already satisfied: tiktoken in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: regex in /usr/local/python/3.12.1/lib/python3.12/site-packages (from tiktoken) (2026.7.19)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->tiktoken) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->tiktoken) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->tiktoken) (2026.2.25)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: /usr/local/python/3.12.1/bin/python3 -m pip install --upgrade pip

# %% [markdown]
# # Count the r's in "strawberry"

# %%
strawberry = tokenizer.encode('strawberry')

for t in strawberry:
  print(f'{t:5d} = {tokenizer.decode([t])}')
# Out:
#   496 = str
#   675 = aw
# 15717 = berry

# %%
r = tokenizer.encode('r')
print(f'{r} = {tokenizer.decode(r)}')
# Out:
# [81] = r

# %%
r in strawberry
# Out:
# False

# %% [markdown]
# # Conclusion: There are no "r"s in "strawberry!

# %%
# decode the encoding to get back to a string for the word
strawberry_string = tokenizer.decode(strawberry)
strawberry_string

# %%
# and for the letter
r_string = tokenizer.decode(r)
r_string

# %%
# and now we can get the correct answer!
strawberry_string.count(r_string)
